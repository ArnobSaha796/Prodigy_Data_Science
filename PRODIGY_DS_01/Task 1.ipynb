# %% [markdown]
# # Task 1

# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading CSV files

# %% [markdown]
# df = pd.read_csv("API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv", skiprows=4)
# df.head()

# %% [markdown]
# ## Chechking top 5 rows data

# %%
df.head(5)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %% [markdown]
# ## Chechking data from bottom

# %%
df.tail(5)
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    984846.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5532301.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16440172.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3153729.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3809389.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261   1011421.0   1036950.0   1062737.0   1090270.0   1120168.0  ...
# 262   5655232.0   5782221.0   5911135.0   6048006.0   6195593.0  ...
# 263  16908035.0  17418522.0  17954564.0  18511361.0  19089380.0  ...
# 264   3254086.0   3358099.0   3465907.0   3577017.0   3692086.0  ...
# 265   3930401.0   4055959.0   4185877.0   4320006.0   4458462.0  ...
#
#            2016        2017        2018        2019        2020        2021  \
# ...

# %% [markdown]
# ## Checking the columns of the dataset

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='str')

# %% [markdown]
# ## Some info about dataset

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 70 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    str
#  1   Country Code    266 non-null    str
#  2   Indicator Name  266 non-null    str
#  3   Indicator Code  266 non-null    str
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.154023e+08  1.170070e+08  1.191678e+08  1.218381e+08  1.245322e+08
# std    3.616526e+08  3.661347e+08  3.727681e+08  3.813687e+08  3.900162e+08
# min    2.715000e+03  2.970000e+03  3.264000e+03  3.584000e+03  3.922000e+03
# 25%    5.152028e+05  5.255230e+05  5.363018e+05  5.475875e+05  5.593638e+05
# 50%    3.659633e+06  3.747132e+06  3.831900e+06  3.919710e+06  4.010150e+06
# 75%    2.686293e+07  2.761326e+07  2.837302e+07  2.915448e+07  2.995223e+07
# max    3.021513e+09  3.062768e+09  3.117372e+09  3.184063e+09  3.251253e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.272581e+08  1.301037e+08  1.329570e+08  1.358851e+08  1.389115e+08
# ...

# %% [markdown]
# ## Chechking for duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Chechking for missing values

# %%
df.isna().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                2
#                  ...
# 2021                1
# 2022                1
# 2023                1
# 2024                1
# Unnamed: 69       266
# Length: 70, dtype: int64

# %% [markdown]
# ## Chechking unique values for columns

# %%
print(df['Country Name'].unique())
print("\n Total number of unique countries:",df['Country Name'].nunique())
# Out:
# <StringArray>
# [                      'Aruba', 'Africa Eastern and Southern',
#                  'Afghanistan',  'Africa Western and Central',
#                       'Angola',                     'Albania',
#                      'Andorra',                  'Arab World',
#         'United Arab Emirates',                   'Argentina',
#  ...
#        'Virgin Islands (U.S.)',                    'Viet Nam',
#                      'Vanuatu',                       'World',
#                        'Samoa',                      'Kosovo',
#                  'Yemen, Rep.',                'South Africa',
#                       'Zambia',                    'Zimbabwe']
# Length: 266, dtype: str
#
#  Total number of unique countries: 266

# %%
print(df['Country Code'].unique())
print("\n Total number of unique country code:",df['Country Code'].nunique())
# Out:
# <StringArray>
# ['ABW', 'AFE', 'AFG', 'AFW', 'AGO', 'ALB', 'AND', 'ARB', 'ARE', 'ARG',
#  ...
#  'VIR', 'VNM', 'VUT', 'WLD', 'WSM', 'XKX', 'YEM', 'ZAF', 'ZMB', 'ZWE']
# Length: 266, dtype: str
#
#  Total number of unique country code: 266

# %% [markdown]
# ## Dropping unnecessary columns

# %%
df.drop(['Indicator Name','Country Name'],axis=1,inplace=True)

# %% [markdown]
# ## Extraction of top 10 countries with respect to total population

# %%
#Filter data for total population
total_population_data = df [df[ 'Indicator Code'] == 'SP.POP.TOTL']
    
#Sort data based on the total population for 2022
total_population_sorted = total_population_data.sort_values (by="2022", ascending=False)

#Get the top ten countries with the highest total population for 2022
total_top_ten_countries = total_population_sorted.head(10)
print("Top ten countries of total population\n")
print (total_top_ten_countries [['Country Code']])
# Out:
# Top ten countries of total population
#
#     Country Code
# 259          WLD
# 103          IBT
# 140          LMY
# 156          MIC
# 102          IBD
# 62           EAR
# 139          LMC
# 249          UMC
# 63           EAS
# 142          LTE

# %% [markdown]
# ## Bar plot

# %% [markdown]
# ## Top 10 countries of total population in year 2024 and 2010

# %%
# Create the bar plot plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="2024", y="Country Code", data=total_top_ten_countries, palette="coolwarm")
plt.title("Top Ten Countries of Total Population (2024)", fontsize=10)
plt.xlabel("Total Population", fontsize=10)
plt.ylabel("Country", fontsize=10)
plt.show()
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot (x="2010", y="Country Code", data=total_top_ten_countries, palette="coolwarm")
plt.title("Top Ten Countries of Total Population (2010)", fontsize=10)
plt.xlabel("Total Population", fontsize=10)
plt.ylabel("Country", fontsize=10)
plt.show()
# Out:
# C:\Users\arnob\AppData\Local\Temp\ipykernel_2700\1959412727.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2024", y="Country Code", data=total_top_ten_countries, palette="coolwarm")
# C:\Users\arnob\AppData\Local\Temp\ipykernel_2700\1959412727.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot (x="2010", y="Country Code", data=total_top_ten_countries, palette="coolwarm")

# %% [markdown]
# ## Extraction of bottom 10 countries with respect to total population

# %%
# Sort data based on the total population for 2024
total_population_sorted1 = total_population_data.sort_values (by="2024", ascending=True)
# Get the top ten countries with the highest total population for 2024
total_bottom_ten_countries = total_population_sorted1.head(10)
print("Bottom ten countries of total population\n")
print (total_bottom_ten_countries [['Country Code']])
# Out:
# Bottom ten countries of total population
#
#     Country Code
# 245          TUV
# 179          NRU
# 188          PLW
# 147          MAF
# 212          SMR
# 155          MHL
# 149          MCO
# 84           GIB
# 255          VGB
# 137          LIE

# %% [markdown]
# ## Bottom 10 countries of total population in year 2024 and 2010

# %%
# Create the bar plot plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="2024", y="Country Code", data=total_bottom_ten_countries, palette="coolwarm")
plt.title("Bottom Ten Countries of Total Population (2024)", fontsize=10)
plt.xlabel("Total Population", fontsize=10)
plt.ylabel("Country", fontsize=10)
plt.show()
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot (x="2010", y="Country Code", data=total_bottom_ten_countries, palette="coolwarm")
plt.title("Bottom Ten Countries of Total Population (2010)", fontsize=10)
plt.xlabel("Total Population", fontsize=10)
plt.ylabel("Country", fontsize=10)
plt.show()
# Out:
# C:\Users\arnob\AppData\Local\Temp\ipykernel_2700\98198550.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2024", y="Country Code", data=total_bottom_ten_countries, palette="coolwarm")
# C:\Users\arnob\AppData\Local\Temp\ipykernel_2700\98198550.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot (x="2010", y="Country Code", data=total_bottom_ten_countries, palette="coolwarm")

# %% [markdown]
# ## Select top 10 countries with the highest total population

# %%
top_10_countries = sorted_data.head(10)

# %%
# Create the bar plot for Total Population
plt.figure(figsize=(12,6))
sns.barplot(x="Country Code", y="2022", data=top_10_countries, color="blue", label="Total Population")

plt.xlabel("Country Code")
plt.ylabel("Total Population (2022)")
plt.title("Top 10 Countries/Regions by Population (2022)")
plt.xticks(rotation=45, ha="right")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Select bottom 10 countries with the highest total population

# %%
bottom_10_countries = sorted_data.tail(10)

# %%
# Create the bar plot for Total Population
plt.figure(figsize=(12,6))
sns.barplot(x="Country Code", y="2024", data=bottom_10_countries, color="pink", label="Total Population")

plt.xlabel("Country Code")
plt.ylabel("Total Population (2024)")
plt.title("Top 10 Countries/Regions by Population (2024)")
plt.xticks(rotation=45, ha="right")
plt.legend()
plt.tight_layout()
plt.show()
